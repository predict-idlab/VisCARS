# %%
from funk_svd.dataset import fetch_ml_ratings
from funk_svd import SVD
import pandas as pd
import random
from rdflib import Graph
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import KFold
from tqdm import tqdm

from viscars.evaluation.metrics.factory import MetricFactory, MetricType
from viscars.recommenders import Recommender

# %%
from rdflib.term import Literal, URIRef
from rdflib.namespace import DefinedNamespace, Namespace


class DASHB(DefinedNamespace):
    """
    The Dynamic Dashboard Ontology
    """

    _fail = True

    # Classes
    User: URIRef
    UserGroup: URIRef
    Dashboard: URIRef
    Tab: URIRef
    Widget: URIRef
    Property: URIRef
    Metric: URIRef
    Visualization: URIRef
    ObservationBoundary: URIRef

    # User
    memberOf: URIRef

    # Dashboard
    hasTab: URIRef

    # Tab
    hasWidget: URIRef

    # Widget
    createdBy: URIRef
    hasProperty: URIRef
    visualizedBy: URIRef
    hasObservationBoundary: URIRef

    # Property
    produces: URIRef

    # ObservationBoundary
    hasMinBoundary: Literal
    hasMaxBoundary: Literal
    hasBoundaryLabel: Literal

    _NS = Namespace('http://dynamicdashboard.ilabt.imec.be/broker/ontologies/dashboard#')

# %%
graph = Graph()
graph.parse('data/protego/graph.ttl')
graph.parse('data/protego/protego_zplus.ttl')

print(len(graph))
# Out:
# 36269

# %%
qry = '''
    PREFIX dashb: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/dashboard#>
    PREFIX sosa: <http://www.w3.org/ns/sosa/>
    PREFIX ssn-ext: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/ssn-extension/>

    SELECT ?user ?context ?item WHERE {
        # ?sensor ssn-ext:subSystemOf ?context ;
            sosa:observes ?item .
            
        # ?widget dashb:hasProperty ?item ;
                dashb:createdBy ?user .                
    }
'''

result = list(graph.query(qry))
users = list(set([str(row.user) for row in result]))
items = list(set([str(row.item) for row in result]))
contexts = list(set([str(row.context) for row in result]))

ratings = pd.DataFrame({
    'u_id': [users.index(str(row.user)) for row in result],
    'i_id': [items.index(str(row.item)) for row in result],
    'rating': len(result) * [1],
    'c_id': [contexts.index(str(row.context)) for row in result]
})
print(ratings.head())
# Out:
#    u_id  i_id  rating  c_id
# 0     0    22       1     2
# 1     3    23       1     3
# 2     0    23       1     3
# 3     0    45       1     7
# 4     3     9       1    14

# %%
qry = '''
    PREFIX dashb: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/dashboard#>

    SELECT ?user WHERE {
        # ?user a dashb:User .
    }
'''

users = pd.DataFrame({'id': [str(row.user) for row in graph.query(qry)]})

# %%
qry = '''
    PREFIX dashb: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/dashboard#>
    PREFIX sosa: <http://www.w3.org/ns/sosa/>

    SELECT ?item WHERE {
        # ?item a sosa:ObservableProperty .
    }
'''

items = pd.DataFrame({'id': [str(row.item) for row in graph.query(qry)]})

# %%
print(len(users), len(items))
# Out:
# 4 2826

# %%
df = pd.DataFrame({'u_id': [], 'i_id': [], 'rating': []})

for u_id, row in users.iterrows():
    uid = row['id']
    for i_id, row in items.iterrows():
        iid = row['id']
        row = {'u_id': [u_id], 'i_id': [i_id]}
        if ((ratings['u_id'] == uid) & (ratings['i_id'] == iid)).any():
            row['rating'] = [1]
        else:
            row['rating'] = [0]

        df = pd.concat([df, pd.DataFrame(row)])

df['u_id'] = df['u_id'].astype(int)
df['i_id'] = df['i_id'].astype(int)

print(len(df))
print(len(df[df['rating'] == 1]))
# Out:
# 11304
# 0

# %%
train = ratings.sample(frac=0.8, random_state=7)
val = ratings.drop(train.index.tolist()).sample(frac=0.5, random_state=8)
test = ratings.drop(train.index.tolist()).drop(val.index.tolist())

# %%
svd = SVD(lr=0.001, reg=0.005, n_epochs=100, n_factors=15, 
          early_stopping=True, shuffle=False, min_rating=0, max_rating=1)

svd.fit(X=train, X_val=val)

pred = svd.predict(test)
mae = mean_absolute_error(test['rating'], pred)

print(f'Test MAE: {mae:.2f}')
# Out:
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.8 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 1 sec
# Test MAE: 0.00

# %%
class MatrixFactorization(Recommender):
    def __init__(self, graph: Graph, verbose=False):
        super().__init__(graph, verbose)

    def _build_model(self):
        qry = '''
            PREFIX dashb: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/dashboard#>
            PREFIX sosa: <http://www.w3.org/ns/sosa/>
            PREFIX ssn-ext: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/ssn-extension/>

            SELECT ?user ?context ?item WHERE {
                # ?sensor ssn-ext:subSystemOf ?context ;
                    sosa:observes ?item .

                # ?widget dashb:hasProperty ?item ;
                        dashb:createdBy ?user .                
            }
        '''

        result = list(self.graph.query(qry))
        self.users = list(set([str(row.user) for row in result]))
        self.items = list(set([str(row.item) for row in result]))
        self.contexts = list(set([str(row.context) for row in result]))
        
        model = SVD(lr=0.001, reg=0.005, n_epochs=100, n_factors=15, 
                    early_stopping=True, shuffle=False, min_rating=0, max_rating=1)
        self.model = model
        
    def fit(self, ratings: pd.DataFrame):        
        train = ratings.sample(frac=0.8, random_state=7)
        val = ratings.drop(train.index.tolist())
        
        self.model.fit(X=train, X_val=val)

    def predict(self, uid, cid, *kwargs):   
        # Get all items for context
        qry = f'''
            PREFIX dashb: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/dashboard#>
            PREFIX sosa: <http://www.w3.org/ns/sosa/>
            PREFIX ssn-ext: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/ssn-extension/>

            SELECT ?property WHERE {{
                # ?sensor ssn-ext:subSystemOf <{self.contexts[cid]}> ;
                    sosa:observes ?property .
            }}
        '''
        items = [str(row.property) for row in self.graph.query(qry)]
        
        scores = {}
        for iid in items:
            if iid in self.items:
                i_id = self.items.index(iid)
            else:
                i_id = len(self.items) + items.index(iid)
            
            df_ = pd.DataFrame({'u_id': [u_id], 'i_id': [i_id]})
            scores[i_id] = self.model.predict(df_)[0]

        recommendations = [{'contextId': cid, 'itemId': item, 'score': score} for item, score in scores.items()]
        random.seed()
        random.shuffle(recommendations)
        return sorted(recommendations, key=lambda n: n['score'], reverse=True)

    def top_n(self, uid: [], cid: [], n: int, **kwargs):
        pass

# %%
# Context metadata
qry = '''
    PREFIX dashb: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/dashboard#>
    PREFIX sosa: <http://www.w3.org/ns/sosa/>
    PREFIX ssn-ext: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/ssn-extension/>

    SELECT ?context WHERE {
        # ?sensor ssn-ext:subSystemOf ?context ;
            sosa:observes ?property .
    }
'''
context_metadata = {'id': []}

result = graph.query(qry)
for row in result:
    context_metadata.get('id').append(row[0])
context_metadata_df = pd.DataFrame.from_dict(context_metadata)

# User metadata
qry = '''
    PREFIX dashb: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/dashboard#>

    SELECT ?user ?username ?role WHERE {
        # ?user dashb:memberOf ?role .
    }
'''
user_metadata = {'id': [], 'type': []}

result = graph.query(qry)
for row in result:
    user_metadata.get('id').append(row[0])
    user_metadata.get('type').append(row[1])
user_metadata_df = pd.DataFrame.from_dict(user_metadata)

# Item metadata
qry = '''
    PREFIX dashb: <http://dynamicdashboard.ilabt.imec.be/broker/ontologies/dashboard#>
    PREFIX sosa: <http://www.w3.org/ns/sosa/>

    SELECT ?property WHERE {
        # ?property a sosa:ObservableProperty .
    }
'''
item_metadata = {'id': []}

result = graph.query(qry)
for row in result:
    item_metadata.get('id').append(row[0])
item_metadata_df = pd.DataFrame.from_dict(item_metadata)


def build_subgraph_from_ratings(ratings: pd.DataFrame) -> Graph:
    sub_graph = Graph()

    for idx, row in context_metadata_df.iterrows():
        cid = row['id']
        sub_graph += graph.triples((cid, None, None))
        sub_graph += graph.triples((None, None, cid))

    for idx, row in user_metadata_df.iterrows():
        uid = row['id']
        sub_graph += graph.triples((uid, DASHB.memberOf, None))

    for idx, row in item_metadata_df.iterrows():
        iid = row['id']
        sub_graph += graph.triples((iid, None, None))
        sub_graph += graph.triples((None, None, iid))

    for idx, row in ratings.iterrows():
        uid = row['u_id']
        iid = row['i_id']
        cid = row['c_id']

        sub_graph += graph.triples((uid, None, None))
        sub_graph += graph.triples((None, None, uid))
        sub_graph += graph.triples((iid, None, None))
        sub_graph += graph.triples((None, None, iid))

        sub_graph += graph.triples((cid, None, None))
        sub_graph += graph.triples((None, None, cid))

    return sub_graph

# %%
class KFoldCrossValidation():

    def __init__(self, recommender: Recommender, metrics: [], k=5):
        """
        :param project_id: ID of the project (to load the correct data).
        :param recommender: Recommender
        :param metrics: List of Metrics
        :param k: Number of folds
        """
        self.recommender = recommender
        self.metrics = metrics
        self.k = k

    def evaluate(self, ratings, **kwargs):
        kf = KFold(n_splits=self.k, shuffle=True)

        n_fold = 0

        result = {'folds': [], 'result': {}}
        for train_idx, test_idx in kf.split(ratings):
            train = ratings.iloc[train_idx]
            test = ratings.iloc[test_idx]
            
            self.recommender.fit(train)

            fold_scores = {}

            for uid in tqdm(test['u_id'].unique()):
                df_user = test.loc[test['u_id'] == uid]

                for cid in df_user['c_id']:
                    predictions = self.recommender.predict(uid, cid, **kwargs)
                    recommendations = [r['itemId'] for r in predictions]

                    truth = []
                    t_user = test.loc[test['u_id'] == uid]
                    for idx, row in t_user.iterrows():
                        if row['c_id'] == cid:
                            truth.append(row['i_id'])
                    # truth = list(test.loc[test['user'] == uid].loc[test['context'] == cid]['item'])
                    print(predictions)
                    print(recommendations)
                    print(truth)
                    
                    for metric in self.metrics:
                        if str(metric) not in fold_scores.keys():
                            fold_scores[str(metric)] = []
                        score = metric.calculate(recommendations, truth)
                        fold_scores[str(metric)].append(score)

            result_for_fold = {}
            for metric, scores in fold_scores.items():
                avg = sum(scores) / len(scores)
                result_for_fold[metric] = avg

                if metric not in result['result'].keys():
                    result['result'][metric] = []
                result['result'][metric].append(avg)
            result['folds'].append(result_for_fold)

            n_fold += 1

        final_results = {}
        for metric_type, score in result['result'].items():
            final_results[metric_type] = sum(score) / len(score)

        result['result'] = final_results
        return result

# %%
metric_factory = MetricFactory()

metrics = ['f1@1', 'ndcg@1', 'ndcg@3']
parsed_metrics = []
for metric in metrics:
    m_split = metric.split('@')
    m_type = m_split[0]
    n = int(m_split[1]) if len(m_split) >= 2 else None

    metric_ = metric_factory.get(MetricType.reverse_lookup(m_type), n)
    parsed_metrics.append(metric_)

# %%
recommender = MatrixFactorization(graph)

evaluator = KFoldCrossValidation(recommender, metrics=parsed_metrics, k=5)
result = evaluator.evaluate(ratings)

for fold in result['folds']:
    print(fold)
print(result['result'])
# Out:
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 37.18it/s]
# [{'contextId': 2, 'itemId': 49, 'score': 1}, {'contextId': 2, 'itemId': 48, 'score': 1}, {'contextId': 2, 'itemId': 55, 'score': 1}, {'contextId': 2, 'itemId': 53, 'score': 1}, {'contextId': 2, 'itemId': 56, 'score': 1}, {'contextId': 2, 'itemId': 52, 'score': 1}, {'contextId': 2, 'itemId': 22, 'score': 1}, {'contextId': 2, 'itemId': 26, 'score': 1}, {'contextId': 2, 'itemId': 51, 'score': 1}, {'contextId': 2, 'itemId': 54, 'score': 1}]
# [49, 48, 55, 53, 56, 52, 22, 26, 51, 54]
# [22]
# [{'contextId': 7, 'itemId': 50, 'score': 1}, {'contextId': 7, 'itemId': 54, 'score': 1}, {'contextId': 7, 'itemId': 2, 'score': 1}, {'contextId': 7, 'itemId': 53, 'score': 1}, {'contextId': 7, 'itemId': 56, 'score': 1}, {'contextId': 7, 'itemId': 37, 'score': 1}, {'contextId': 7, 'itemId': 55, 'score': 1}, {'contextId': 7, 'itemId': 49, 'score': 1}, {'contextId': 7, 'itemId': 45, 'score': 0.9846470105683822}, {'contextId': 7, 'itemId': 1, 'score': 0.9530662735724774}]
# [50, 54, 2, 53, 56, 37, 55, 49, 45, 1]
# [37]
# [{'contextId': 1, 'itemId': 48, 'score': 1}, {'contextId': 1, 'itemId': 54, 'score': 1}, {'contextId': 1, 'itemId': 53, 'score': 1}, {'contextId': 1, 'itemId': 27, 'score': 1}, {'contextId': 1, 'itemId': 5, 'score': 1}, {'contextId': 1, 'itemId': 47, 'score': 1}, {'contextId': 1, 'itemId': 55, 'score': 1}, {'contextId': 1, 'itemId': 39, 'score': 1}, {'contextId': 1, 'itemId': 49, 'score': 1}, {'contextId': 1, 'itemId': 20, 'score': 0.9938860542683355}]
# [48, 54, 53, 27, 5, 47, 55, 39, 49, 20]
# [39, 5]
# [{'contextId': 1, 'itemId': 55, 'score': 1}, {'contextId': 1, 'itemId': 53, 'score': 1}, {'contextId': 1, 'itemId': 39, 'score': 1}, {'contextId': 1, 'itemId': 54, 'score': 1}, {'contextId': 1, 'itemId': 5, 'score': 1}, {'contextId': 1, 'itemId': 48, 'score': 1}, {'contextId': 1, 'itemId': 27, 'score': 1}, {'contextId': 1, 'itemId': 49, 'score': 1}, {'contextId': 1, 'itemId': 47, 'score': 1}, {'contextId': 1, 'itemId': 20, 'score': 0.9938860542683355}]
# [55, 53, 39, 54, 5, 48, 27, 49, 47, 20]
# [39, 5]
# [{'contextId': 14, 'itemId': 55, 'score': 1}, {'contextId': 14, 'itemId': 54, 'score': 1}, {'contextId': 14, 'itemId': 53, 'score': 1}, {'contextId': 14, 'itemId': 50, 'score': 1}, {'contextId': 14, 'itemId': 51, 'score': 1}, {'contextId': 14, 'itemId': 9, 'score': 1}, {'contextId': 14, 'itemId': 49, 'score': 1}, {'contextId': 14, 'itemId': 56, 'score': 1}, {'contextId': 14, 'itemId': 52, 'score': 1}, {'contextId': 14, 'itemId': 24, 'score': 0.9764610434187061}]
# [55, 54, 53, 50, 51, 9, 49, 56, 52, 24]
# [9]
# [{'contextId': 15, 'itemId': 50, 'score': 1}, {'contextId': 15, 'itemId': 42, 'score': 1}, {'contextId': 15, 'itemId': 53, 'score': 1}, {'contextId': 15, 'itemId': 41, 'score': 1}, {'contextId': 15, 'itemId': 14, 'score': 1}, {'contextId': 15, 'itemId': 56, 'score': 1}, {'contextId': 15, 'itemId': 55, 'score': 1}, {'contextId': 15, 'itemId': 48, 'score': 1}, {'contextId': 15, 'itemId': 49, 'score': 1}, {'contextId': 15, 'itemId': 54, 'score': 1}]
# [50, 42, 53, 41, 14, 56, 55, 48, 49, 54]
# [41]
# [{'contextId': 16, 'itemId': 53, 'score': 1}, {'contextId': 16, 'itemId': 51, 'score': 1}, {'contextId': 16, 'itemId': 54, 'score': 1}, {'contextId': 16, 'itemId': 52, 'score': 1}, {'contextId': 16, 'itemId': 50, 'score': 1}, {'contextId': 16, 'itemId': 48, 'score': 1}, {'contextId': 16, 'itemId': 28, 'score': 1}, {'contextId': 16, 'itemId': 49, 'score': 1}, {'contextId': 16, 'itemId': 56, 'score': 1}, {'contextId': 16, 'itemId': 55, 'score': 1}]
# [53, 51, 54, 52, 50, 48, 28, 49, 56, 55]
# [28]
# [{'contextId': 9, 'itemId': 25, 'score': 1}, {'contextId': 9, 'itemId': 54, 'score': 1}, {'contextId': 9, 'itemId': 49, 'score': 1}, {'contextId': 9, 'itemId': 56, 'score': 1}, {'contextId': 9, 'itemId': 55, 'score': 1}, {'contextId': 9, 'itemId': 52, 'score': 1}, {'contextId': 9, 'itemId': 51, 'score': 1}, {'contextId': 9, 'itemId': 15, 'score': 1}, {'contextId': 9, 'itemId': 53, 'score': 1}, {'contextId': 9, 'itemId': 46, 'score': 0.993055475534343}]
# [25, 54, 49, 56, 55, 52, 51, 15, 53, 46]
# [15]
# [{'contextId': 10, 'itemId': 17, 'score': 1}, {'contextId': 10, 'itemId': 50, 'score': 1}, {'contextId': 10, 'itemId': 56, 'score': 1}, {'contextId': 10, 'itemId': 49, 'score': 1}, {'contextId': 10, 'itemId': 16, 'score': 1}, {'contextId': 10, 'itemId': 48, 'score': 1}, {'contextId': 10, 'itemId': 53, 'score': 1}, {'contextId': 10, 'itemId': 12, 'score': 1}, {'contextId': 10, 'itemId': 55, 'score': 1}, {'contextId': 10, 'itemId': 54, 'score': 1}]
# [17, 50, 56, 49, 16, 48, 53, 12, 55, 54]
# [16]
# [{'contextId': 13, 'itemId': 55, 'score': 1}, {'contextId': 13, 'itemId': 54, 'score': 1}, {'contextId': 13, 'itemId': 56, 'score': 1}, {'contextId': 13, 'itemId': 51, 'score': 1}, {'contextId': 13, 'itemId': 52, 'score': 1}, {'contextId': 13, 'itemId': 40, 'score': 1}, {'contextId': 13, 'itemId': 33, 'score': 1}, {'contextId': 13, 'itemId': 49, 'score': 1}, {'contextId': 13, 'itemId': 53, 'score': 1}, {'contextId': 13, 'itemId': 3, 'score': 0.9833053813518151}]
# [55, 54, 56, 51, 52, 40, 33, 49, 53, 3]
# [33]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 44.08it/s]
# [{'contextId': 10, 'itemId': 50, 'score': 1}, {'contextId': 10, 'itemId': 54, 'score': 1}, {'contextId': 10, 'itemId': 16, 'score': 1}, {'contextId': 10, 'itemId': 48, 'score': 1}, {'contextId': 10, 'itemId': 12, 'score': 1}, {'contextId': 10, 'itemId': 53, 'score': 1}, {'contextId': 10, 'itemId': 49, 'score': 1}, {'contextId': 10, 'itemId': 55, 'score': 1}, {'contextId': 10, 'itemId': 56, 'score': 1}, {'contextId': 10, 'itemId': 17, 'score': 0.9733051371212954}]
# [50, 54, 16, 48, 12, 53, 49, 55, 56, 17]
# [12]
# [{'contextId': 13, 'itemId': 55, 'score': 1}, {'contextId': 13, 'itemId': 54, 'score': 1}, {'contextId': 13, 'itemId': 49, 'score': 1}, {'contextId': 13, 'itemId': 52, 'score': 1}, {'contextId': 13, 'itemId': 3, 'score': 1}, {'contextId': 13, 'itemId': 53, 'score': 1}, {'contextId': 13, 'itemId': 51, 'score': 1}, {'contextId': 13, 'itemId': 40, 'score': 1}, {'contextId': 13, 'itemId': 56, 'score': 1}, {'contextId': 13, 'itemId': 33, 'score': 0.9800663877967742}]
# [55, 54, 49, 52, 3, 53, 51, 40, 56, 33]
# [3]
# [{'contextId': 9, 'itemId': 51, 'score': 1}, {'contextId': 9, 'itemId': 53, 'score': 1}, {'contextId': 9, 'itemId': 56, 'score': 1}, {'contextId': 9, 'itemId': 49, 'score': 1}, {'contextId': 9, 'itemId': 55, 'score': 1}, {'contextId': 9, 'itemId': 52, 'score': 1}, {'contextId': 9, 'itemId': 25, 'score': 1}, {'contextId': 9, 'itemId': 54, 'score': 1}, {'contextId': 9, 'itemId': 15, 'score': 0.9925021621282046}, {'contextId': 9, 'itemId': 46, 'score': 0.9072947310795407}]
# [51, 53, 56, 49, 55, 52, 25, 54, 15, 46]
# [25]
# [{'contextId': 8, 'itemId': 56, 'score': 1}, {'contextId': 8, 'itemId': 49, 'score': 1}, {'contextId': 8, 'itemId': 51, 'score': 1}, {'contextId': 8, 'itemId': 54, 'score': 1}, {'contextId': 8, 'itemId': 53, 'score': 1}, {'contextId': 8, 'itemId': 50, 'score': 1}, {'contextId': 8, 'itemId': 52, 'score': 1}, {'contextId': 8, 'itemId': 48, 'score': 1}, {'contextId': 8, 'itemId': 4, 'score': 1}, {'contextId': 8, 'itemId': 55, 'score': 1}]
# [56, 49, 51, 54, 53, 50, 52, 48, 4, 55]
# [4]
# [{'contextId': 4, 'itemId': 49, 'score': 1}, {'contextId': 4, 'itemId': 53, 'score': 1}, {'contextId': 4, 'itemId': 13, 'score': 1}, {'contextId': 4, 'itemId': 38, 'score': 1}, {'contextId': 4, 'itemId': 56, 'score': 1}, {'contextId': 4, 'itemId': 55, 'score': 1}, {'contextId': 4, 'itemId': 6, 'score': 1}, {'contextId': 4, 'itemId': 54, 'score': 1}, {'contextId': 4, 'itemId': 50, 'score': 1}, {'contextId': 4, 'itemId': 0, 'score': 1}]
# [49, 53, 13, 38, 56, 55, 6, 54, 50, 0]
# [6]
# [{'contextId': 3, 'itemId': 52, 'score': 1}, {'contextId': 3, 'itemId': 36, 'score': 1}, {'contextId': 3, 'itemId': 55, 'score': 1}, {'contextId': 3, 'itemId': 51, 'score': 1}, {'contextId': 3, 'itemId': 54, 'score': 1}, {'contextId': 3, 'itemId': 56, 'score': 1}, {'contextId': 3, 'itemId': 49, 'score': 1}, {'contextId': 3, 'itemId': 53, 'score': 1}, {'contextId': 3, 'itemId': 50, 'score': 1}, {'contextId': 3, 'itemId': 23, 'score': 0.9816524017695796}]
# [52, 36, 55, 51, 54, 56, 49, 53, 50, 23]
# [36]
# [{'contextId': 15, 'itemId': 50, 'score': 1}, {'contextId': 15, 'itemId': 14, 'score': 1}, {'contextId': 15, 'itemId': 42, 'score': 1}, {'contextId': 15, 'itemId': 49, 'score': 1}, {'contextId': 15, 'itemId': 53, 'score': 1}, {'contextId': 15, 'itemId': 48, 'score': 1}, {'contextId': 15, 'itemId': 56, 'score': 1}, {'contextId': 15, 'itemId': 55, 'score': 1}, {'contextId': 15, 'itemId': 54, 'score': 1}, {'contextId': 15, 'itemId': 41, 'score': 0.971505135568844}]
# [50, 14, 42, 49, 53, 48, 56, 55, 54, 41]
# [42]
# [{'contextId': 1, 'itemId': 20, 'score': 1}, {'contextId': 1, 'itemId': 27, 'score': 1}, {'contextId': 1, 'itemId': 53, 'score': 1}, {'contextId': 1, 'itemId': 54, 'score': 1}, {'contextId': 1, 'itemId': 48, 'score': 1}, {'contextId': 1, 'itemId': 49, 'score': 1}, {'contextId': 1, 'itemId': 55, 'score': 1}, {'contextId': 1, 'itemId': 47, 'score': 1}, {'contextId': 1, 'itemId': 39, 'score': 0.9887532328351178}, {'contextId': 1, 'itemId': 5, 'score': 0.9699661755407925}]
# [20, 27, 53, 54, 48, 49, 55, 47, 39, 5]
# [27]
# [{'contextId': 12, 'itemId': 56, 'score': 1}, {'contextId': 12, 'itemId': 31, 'score': 1}, {'contextId': 12, 'itemId': 49, 'score': 1}, {'contextId': 12, 'itemId': 18, 'score': 1}, {'contextId': 12, 'itemId': 48, 'score': 1}, {'contextId': 12, 'itemId': 53, 'score': 1}, {'contextId': 12, 'itemId': 34, 'score': 1}, {'contextId': 12, 'itemId': 55, 'score': 1}, {'contextId': 12, 'itemId': 54, 'score': 1}, {'contextId': 12, 'itemId': 50, 'score': 1}]
# [56, 31, 49, 18, 48, 53, 34, 55, 54, 50]
# [18, 31]
# [{'contextId': 12, 'itemId': 54, 'score': 1}, {'contextId': 12, 'itemId': 53, 'score': 1}, {'contextId': 12, 'itemId': 49, 'score': 1}, {'contextId': 12, 'itemId': 56, 'score': 1}, {'contextId': 12, 'itemId': 34, 'score': 1}, {'contextId': 12, 'itemId': 18, 'score': 1}, {'contextId': 12, 'itemId': 48, 'score': 1}, {'contextId': 12, 'itemId': 31, 'score': 1}, {'contextId': 12, 'itemId': 50, 'score': 1}, {'contextId': 12, 'itemId': 55, 'score': 1}]
# [54, 53, 49, 56, 34, 18, 48, 31, 50, 55]
# [18, 31]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
#   0%|                                                     | 0/3 [00:00<?, ?it/s]
# [{'contextId': 3, 'itemId': 53, 'score': 1}, {'contextId': 3, 'itemId': 36, 'score': 1}, {'contextId': 3, 'itemId': 49, 'score': 1}, {'contextId': 3, 'itemId': 55, 'score': 1}, {'contextId': 3, 'itemId': 54, 'score': 1}, {'contextId': 3, 'itemId': 50, 'score': 1}, {'contextId': 3, 'itemId': 52, 'score': 1}, {'contextId': 3, 'itemId': 56, 'score': 1}, {'contextId': 3, 'itemId': 51, 'score': 1}, {'contextId': 3, 'itemId': 23, 'score': 0.9862147405048413}]
# [53, 36, 49, 55, 54, 50, 52, 56, 51, 23]
# [23]
# [{'contextId': 6, 'itemId': 10, 'score': 1}, {'contextId': 6, 'itemId': 11, 'score': 1}, {'contextId': 6, 'itemId': 56, 'score': 1}, {'contextId': 6, 'itemId': 49, 'score': 1}, {'contextId': 6, 'itemId': 48, 'score': 1}, {'contextId': 6, 'itemId': 53, 'score': 1}, {'contextId': 6, 'itemId': 50, 'score': 1}, {'contextId': 6, 'itemId': 51, 'score': 1}, {'contextId': 6, 'itemId': 52, 'score': 1}, {'contextId': 6, 'itemId': 55, 'score': 1}]
# [10, 11, 56, 49, 48, 53, 50, 51, 52, 55]
# [10]
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00, 35.17it/s]
# [{'contextId': 17, 'itemId': 52, 'score': 1}, {'contextId': 17, 'itemId': 48, 'score': 1}, {'contextId': 17, 'itemId': 55, 'score': 1}, {'contextId': 17, 'itemId': 56, 'score': 1}, {'contextId': 17, 'itemId': 50, 'score': 1}, {'contextId': 17, 'itemId': 49, 'score': 1}, {'contextId': 17, 'itemId': 53, 'score': 1}, {'contextId': 17, 'itemId': 8, 'score': 1}, {'contextId': 17, 'itemId': 51, 'score': 1}, {'contextId': 17, 'itemId': 19, 'score': 1}]
# [52, 48, 55, 56, 50, 49, 53, 8, 51, 19]
# [19]
# [{'contextId': 7, 'itemId': 55, 'score': 1}, {'contextId': 7, 'itemId': 53, 'score': 1}, {'contextId': 7, 'itemId': 50, 'score': 1}, {'contextId': 7, 'itemId': 56, 'score': 1}, {'contextId': 7, 'itemId': 45, 'score': 1}, {'contextId': 7, 'itemId': 1, 'score': 1}, {'contextId': 7, 'itemId': 49, 'score': 1}, {'contextId': 7, 'itemId': 54, 'score': 1}, {'contextId': 7, 'itemId': 2, 'score': 1}, {'contextId': 7, 'itemId': 37, 'score': 0.9309748382380031}]
# [55, 53, 50, 56, 45, 1, 49, 54, 2, 37]
# [1]
# [{'contextId': 2, 'itemId': 48, 'score': 1}, {'contextId': 2, 'itemId': 26, 'score': 1}, {'contextId': 2, 'itemId': 53, 'score': 1}, {'contextId': 2, 'itemId': 56, 'score': 1}, {'contextId': 2, 'itemId': 54, 'score': 1}, {'contextId': 2, 'itemId': 51, 'score': 1}, {'contextId': 2, 'itemId': 49, 'score': 1}, {'contextId': 2, 'itemId': 52, 'score': 1}, {'contextId': 2, 'itemId': 55, 'score': 1}, {'contextId': 2, 'itemId': 22, 'score': 0.9066181467831482}]
# [48, 26, 53, 56, 54, 51, 49, 52, 55, 22]
# [26]
# [{'contextId': 13, 'itemId': 55, 'score': 1}, {'contextId': 13, 'itemId': 54, 'score': 1}, {'contextId': 13, 'itemId': 49, 'score': 1}, {'contextId': 13, 'itemId': 53, 'score': 1}, {'contextId': 13, 'itemId': 51, 'score': 1}, {'contextId': 13, 'itemId': 40, 'score': 1}, {'contextId': 13, 'itemId': 52, 'score': 1}, {'contextId': 13, 'itemId': 56, 'score': 1}, {'contextId': 13, 'itemId': 33, 'score': 1}, {'contextId': 13, 'itemId': 3, 'score': 0.9857805984062468}]
# [55, 54, 49, 53, 51, 40, 52, 56, 33, 3]
# [40]
# [{'contextId': 9, 'itemId': 54, 'score': 1}, {'contextId': 9, 'itemId': 49, 'score': 1}, {'contextId': 9, 'itemId': 51, 'score': 1}, {'contextId': 9, 'itemId': 55, 'score': 1}, {'contextId': 9, 'itemId': 56, 'score': 1}, {'contextId': 9, 'itemId': 25, 'score': 1}, {'contextId': 9, 'itemId': 46, 'score': 1}, {'contextId': 9, 'itemId': 53, 'score': 1}, {'contextId': 9, 'itemId': 52, 'score': 1}, {'contextId': 9, 'itemId': 15, 'score': 1}]
# [54, 49, 51, 55, 56, 25, 46, 53, 52, 15]
# [46]
# [{'contextId': 18, 'itemId': 52, 'score': 1}, {'contextId': 18, 'itemId': 50, 'score': 1}, {'contextId': 18, 'itemId': 51, 'score': 1}, {'contextId': 18, 'itemId': 7, 'score': 1}, {'contextId': 18, 'itemId': 55, 'score': 1}, {'contextId': 18, 'itemId': 53, 'score': 1}, {'contextId': 18, 'itemId': 49, 'score': 1}, {'contextId': 18, 'itemId': 54, 'score': 1}, {'contextId': 18, 'itemId': 56, 'score': 1}, {'contextId': 18, 'itemId': 48, 'score': 1}]
# [52, 50, 51, 7, 55, 53, 49, 54, 56, 48]
# [7]
# [{'contextId': 11, 'itemId': 50, 'score': 1}, {'contextId': 11, 'itemId': 49, 'score': 1}, {'contextId': 11, 'itemId': 56, 'score': 1}, {'contextId': 11, 'itemId': 29, 'score': 1}, {'contextId': 11, 'itemId': 35, 'score': 1}, {'contextId': 11, 'itemId': 30, 'score': 1}, {'contextId': 11, 'itemId': 51, 'score': 1}, {'contextId': 11, 'itemId': 53, 'score': 1}, {'contextId': 11, 'itemId': 52, 'score': 1}, {'contextId': 11, 'itemId': 55, 'score': 1}]
# [50, 49, 56, 29, 35, 30, 51, 53, 52, 55]
# [35, 29]
# [{'contextId': 11, 'itemId': 51, 'score': 1}, {'contextId': 11, 'itemId': 53, 'score': 1}, {'contextId': 11, 'itemId': 52, 'score': 1}, {'contextId': 11, 'itemId': 29, 'score': 1}, {'contextId': 11, 'itemId': 50, 'score': 1}, {'contextId': 11, 'itemId': 56, 'score': 1}, {'contextId': 11, 'itemId': 49, 'score': 1}, {'contextId': 11, 'itemId': 55, 'score': 1}, {'contextId': 11, 'itemId': 30, 'score': 1}, {'contextId': 11, 'itemId': 35, 'score': 1}]
# [51, 53, 52, 29, 50, 56, 49, 55, 30, 35]
# [35, 29]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
# [{'contextId': 3, 'itemId': 36, 'score': 1}, {'contextId': 3, 'itemId': 53, 'score': 0.9999911469462187}, {'contextId': 3, 'itemId': 49, 'score': 0.9999911469462187}, {'contextId': 3, 'itemId': 55, 'score': 0.9999911469462187}, {'contextId': 3, 'itemId': 56, 'score': 0.9999911469462187}, {'contextId': 3, 'itemId': 54, 'score': 0.9999911469462187}, {'contextId': 3, 'itemId': 52, 'score': 0.9999911469462187}, {'contextId': 3, 'itemId': 51, 'score': 0.9999911469462187}, {'contextId': 3, 'itemId': 50, 'score': 0.9999911469462187}, {'contextId': 3, 'itemId': 23, 'score': 0.9946963757854176}]
# [36, 53, 49, 55, 56, 54, 52, 51, 50, 23]
# [23]
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 46.17it/s]
# [{'contextId': 14, 'itemId': 24, 'score': 0.9999911469462187}, {'contextId': 14, 'itemId': 50, 'score': 0.9999911469462187}, {'contextId': 14, 'itemId': 52, 'score': 0.9999911469462187}, {'contextId': 14, 'itemId': 51, 'score': 0.9999911469462187}, {'contextId': 14, 'itemId': 54, 'score': 0.9999911469462187}, {'contextId': 14, 'itemId': 49, 'score': 0.9999911469462187}, {'contextId': 14, 'itemId': 56, 'score': 0.9999911469462187}, {'contextId': 14, 'itemId': 53, 'score': 0.9999911469462187}, {'contextId': 14, 'itemId': 55, 'score': 0.9999911469462187}, {'contextId': 14, 'itemId': 9, 'score': 0.9796813394400548}]
# [24, 50, 52, 51, 54, 49, 56, 53, 55, 9]
# [24]
# [{'contextId': 4, 'itemId': 50, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 53, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 55, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 56, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 54, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 38, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 49, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 0, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 6, 'score': 0.9846536451020808}, {'contextId': 4, 'itemId': 13, 'score': 0.9742031873810485}]
# [50, 53, 55, 56, 54, 38, 49, 0, 6, 13]
# [38, 0]
# [{'contextId': 4, 'itemId': 56, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 54, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 0, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 50, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 53, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 55, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 49, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 38, 'score': 0.9999911469462187}, {'contextId': 4, 'itemId': 6, 'score': 0.9846536451020808}, {'contextId': 4, 'itemId': 13, 'score': 0.9742031873810485}]
# [56, 54, 0, 50, 53, 55, 49, 38, 6, 13]
# [38, 0]
# [{'contextId': 7, 'itemId': 54, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 55, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 50, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 37, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 1, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 49, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 45, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 2, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 53, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 56, 'score': 0.9999911469462187}]
# [54, 55, 50, 37, 1, 49, 45, 2, 53, 56]
# [45, 2]
# [{'contextId': 7, 'itemId': 53, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 50, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 45, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 49, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 1, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 56, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 55, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 2, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 37, 'score': 0.9999911469462187}, {'contextId': 7, 'itemId': 54, 'score': 0.9999911469462187}]
# [53, 50, 45, 49, 1, 56, 55, 2, 37, 54]
# [45, 2]
# [{'contextId': 6, 'itemId': 50, 'score': 0.9999911469462187}, {'contextId': 6, 'itemId': 53, 'score': 0.9999911469462187}, {'contextId': 6, 'itemId': 56, 'score': 0.9999911469462187}, {'contextId': 6, 'itemId': 11, 'score': 0.9999911469462187}, {'contextId': 6, 'itemId': 55, 'score': 0.9999911469462187}, {'contextId': 6, 'itemId': 49, 'score': 0.9999911469462187}, {'contextId': 6, 'itemId': 52, 'score': 0.9999911469462187}, {'contextId': 6, 'itemId': 48, 'score': 0.9999911469462187}, {'contextId': 6, 'itemId': 51, 'score': 0.9999911469462187}, {'contextId': 6, 'itemId': 10, 'score': 0.9985706135428163}]
# [50, 53, 56, 11, 55, 49, 52, 48, 51, 10]
# [11]
# [{'contextId': 5, 'itemId': 32, 'score': 1}, {'contextId': 5, 'itemId': 54, 'score': 0.9999911469462187}, {'contextId': 5, 'itemId': 51, 'score': 0.9999911469462187}, {'contextId': 5, 'itemId': 53, 'score': 0.9999911469462187}, {'contextId': 5, 'itemId': 50, 'score': 0.9999911469462187}, {'contextId': 5, 'itemId': 21, 'score': 0.9999911469462187}, {'contextId': 5, 'itemId': 56, 'score': 0.9999911469462187}, {'contextId': 5, 'itemId': 49, 'score': 0.9999911469462187}, {'contextId': 5, 'itemId': 55, 'score': 0.9999911469462187}, {'contextId': 5, 'itemId': 52, 'score': 0.9999911469462187}]
# [32, 54, 51, 53, 50, 21, 56, 49, 55, 52]
# [21]
# [{'contextId': 10, 'itemId': 16, 'score': 1}, {'contextId': 10, 'itemId': 17, 'score': 0.9999911469462187}, {'contextId': 10, 'itemId': 53, 'score': 0.9999911469462187}, {'contextId': 10, 'itemId': 55, 'score': 0.9999911469462187}, {'contextId': 10, 'itemId': 50, 'score': 0.9999911469462187}, {'contextId': 10, 'itemId': 56, 'score': 0.9999911469462187}, {'contextId': 10, 'itemId': 48, 'score': 0.9999911469462187}, {'contextId': 10, 'itemId': 54, 'score': 0.9999911469462187}, {'contextId': 10, 'itemId': 49, 'score': 0.9999911469462187}, {'contextId': 10, 'itemId': 12, 'score': 0.9894321834818329}]
# [16, 17, 53, 55, 50, 56, 48, 54, 49, 12]
# [17]
# [{'contextId': 0, 'itemId': 51, 'score': 0.9999911469462187}, {'contextId': 0, 'itemId': 53, 'score': 0.9999911469462187}, {'contextId': 0, 'itemId': 56, 'score': 0.9999911469462187}, {'contextId': 0, 'itemId': 55, 'score': 0.9999911469462187}, {'contextId': 0, 'itemId': 49, 'score': 0.9999911469462187}, {'contextId': 0, 'itemId': 54, 'score': 0.9999911469462187}, {'contextId': 0, 'itemId': 43, 'score': 0.9999911469462187}, {'contextId': 0, 'itemId': 50, 'score': 0.9999911469462187}, {'contextId': 0, 'itemId': 52, 'score': 0.9999911469462187}, {'contextId': 0, 'itemId': 44, 'score': 0.9924226263681649}]
# [51, 53, 56, 55, 49, 54, 43, 50, 52, 44]
# [43]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
#   0%|                                                     | 0/4 [00:00<?, ?it/s]
# [{'contextId': 12, 'itemId': 18, 'score': 1}, {'contextId': 12, 'itemId': 50, 'score': 1}, {'contextId': 12, 'itemId': 54, 'score': 1}, {'contextId': 12, 'itemId': 34, 'score': 1}, {'contextId': 12, 'itemId': 53, 'score': 1}, {'contextId': 12, 'itemId': 48, 'score': 1}, {'contextId': 12, 'itemId': 49, 'score': 1}, {'contextId': 12, 'itemId': 56, 'score': 1}, {'contextId': 12, 'itemId': 55, 'score': 1}, {'contextId': 12, 'itemId': 31, 'score': 0.9694261026973692}]
# [18, 50, 54, 34, 53, 48, 49, 56, 55, 31]
# [34]
# [{'contextId': 0, 'itemId': 50, 'score': 1}, {'contextId': 0, 'itemId': 51, 'score': 1}, {'contextId': 0, 'itemId': 56, 'score': 1}, {'contextId': 0, 'itemId': 49, 'score': 1}, {'contextId': 0, 'itemId': 44, 'score': 1}, {'contextId': 0, 'itemId': 55, 'score': 1}, {'contextId': 0, 'itemId': 54, 'score': 1}, {'contextId': 0, 'itemId': 53, 'score': 1}, {'contextId': 0, 'itemId': 52, 'score': 1}, {'contextId': 0, 'itemId': 43, 'score': 0.9438403322727204}]
# [50, 51, 56, 49, 44, 55, 54, 53, 52, 43]
# [44]
# [{'contextId': 11, 'itemId': 52, 'score': 1}, {'contextId': 11, 'itemId': 50, 'score': 1}, {'contextId': 11, 'itemId': 30, 'score': 1}, {'contextId': 11, 'itemId': 51, 'score': 1}, {'contextId': 11, 'itemId': 53, 'score': 1}, {'contextId': 11, 'itemId': 35, 'score': 1}, {'contextId': 11, 'itemId': 49, 'score': 1}, {'contextId': 11, 'itemId': 29, 'score': 1}, {'contextId': 11, 'itemId': 55, 'score': 1}, {'contextId': 11, 'itemId': 56, 'score': 1}]
# [52, 50, 30, 51, 53, 35, 49, 29, 55, 56]
# [30]
# [{'contextId': 4, 'itemId': 50, 'score': 1}, {'contextId': 4, 'itemId': 56, 'score': 1}, {'contextId': 4, 'itemId': 49, 'score': 1}, {'contextId': 4, 'itemId': 13, 'score': 1}, {'contextId': 4, 'itemId': 55, 'score': 1}, {'contextId': 4, 'itemId': 54, 'score': 1}, {'contextId': 4, 'itemId': 53, 'score': 1}, {'contextId': 4, 'itemId': 6, 'score': 0.99182030239993}, {'contextId': 4, 'itemId': 0, 'score': 0.9838024803061434}, {'contextId': 4, 'itemId': 38, 'score': 0.935218316962543}]
# [50, 56, 49, 13, 55, 54, 53, 6, 0, 38]
# [13]
# [{'contextId': 15, 'itemId': 50, 'score': 1}, {'contextId': 15, 'itemId': 49, 'score': 1}, {'contextId': 15, 'itemId': 54, 'score': 1}, {'contextId': 15, 'itemId': 14, 'score': 1}, {'contextId': 15, 'itemId': 42, 'score': 1}, {'contextId': 15, 'itemId': 56, 'score': 1}, {'contextId': 15, 'itemId': 53, 'score': 1}, {'contextId': 15, 'itemId': 48, 'score': 1}, {'contextId': 15, 'itemId': 55, 'score': 1}, {'contextId': 15, 'itemId': 41, 'score': 0.9941786258216215}]
# [50, 49, 54, 14, 42, 56, 53, 48, 55, 41]
# [14]
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 50.94it/s]
# [{'contextId': 5, 'itemId': 55, 'score': 1}, {'contextId': 5, 'itemId': 52, 'score': 1}, {'contextId': 5, 'itemId': 54, 'score': 1}, {'contextId': 5, 'itemId': 21, 'score': 1}, {'contextId': 5, 'itemId': 49, 'score': 1}, {'contextId': 5, 'itemId': 50, 'score': 1}, {'contextId': 5, 'itemId': 32, 'score': 1}, {'contextId': 5, 'itemId': 51, 'score': 1}, {'contextId': 5, 'itemId': 56, 'score': 1}, {'contextId': 5, 'itemId': 53, 'score': 1}]
# [55, 52, 54, 21, 49, 50, 32, 51, 56, 53]
# [32]
# [{'contextId': 3, 'itemId': 56, 'score': 1}, {'contextId': 3, 'itemId': 55, 'score': 1}, {'contextId': 3, 'itemId': 50, 'score': 1}, {'contextId': 3, 'itemId': 23, 'score': 1}, {'contextId': 3, 'itemId': 54, 'score': 1}, {'contextId': 3, 'itemId': 36, 'score': 1}, {'contextId': 3, 'itemId': 53, 'score': 1}, {'contextId': 3, 'itemId': 51, 'score': 1}, {'contextId': 3, 'itemId': 49, 'score': 1}, {'contextId': 3, 'itemId': 52, 'score': 1}]
# [56, 55, 50, 23, 54, 36, 53, 51, 49, 52]
# [36]
# [{'contextId': 17, 'itemId': 49, 'score': 1}, {'contextId': 17, 'itemId': 55, 'score': 1}, {'contextId': 17, 'itemId': 53, 'score': 1}, {'contextId': 17, 'itemId': 48, 'score': 1}, {'contextId': 17, 'itemId': 50, 'score': 1}, {'contextId': 17, 'itemId': 52, 'score': 1}, {'contextId': 17, 'itemId': 19, 'score': 1}, {'contextId': 17, 'itemId': 8, 'score': 1}, {'contextId': 17, 'itemId': 51, 'score': 1}, {'contextId': 17, 'itemId': 56, 'score': 1}]
# [49, 55, 53, 48, 50, 52, 19, 8, 51, 56]
# [8]
# [{'contextId': 1, 'itemId': 49, 'score': 1}, {'contextId': 1, 'itemId': 54, 'score': 1}, {'contextId': 1, 'itemId': 20, 'score': 1}, {'contextId': 1, 'itemId': 53, 'score': 1}, {'contextId': 1, 'itemId': 27, 'score': 1}, {'contextId': 1, 'itemId': 55, 'score': 1}, {'contextId': 1, 'itemId': 48, 'score': 1}, {'contextId': 1, 'itemId': 5, 'score': 1}, {'contextId': 1, 'itemId': 47, 'score': 1}, {'contextId': 1, 'itemId': 39, 'score': 0.9883185769079583}]
# [49, 54, 20, 53, 27, 55, 48, 5, 47, 39]
# [20]
# {'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.03065735963827292}
# {'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.21487123143774567}
# {'f1@1': 0.1, 'ndcg@1': 0.1, 'ndcg@3': 0.16309297535714576}
# {'f1@1': 0.1, 'ndcg@1': 0.1, 'ndcg@3': 0.22440769463369162}
# {'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.1111111111111111}
# {'f1@1': 0.04, 'ndcg@1': 0.04, 'ndcg@3': 0.14882807443559343}

# %%
class LeaveOneOutCrossValidation():

    def __init__(self, recommender: Recommender, metrics: []):
        """
        :param recommender: Recommender
        :param metrics: List of Metrics
        :param k: Number of folds
        """
        self.recommender = recommender
        self.metrics = metrics

    def _split_ratings(self, ratings, cid):
        train = ratings[ratings['c_id'] != cid]
        test = ratings[ratings['c_id'] == cid]

        return train, test

    def evaluate(self, ratings, **kwargs):
        result = {'folds': [], 'result': {}}
        
        for cid in ratings['c_id'].unique():
            train, test = self._split_ratings(ratings, cid)

            self.recommender.fit(train)

            fold_scores = {}

            df_context = test.loc[test['c_id'] == cid]

            for uid in df_context['u_id']:
                predictions = self.recommender.predict(uid, cid, **kwargs)
                recommendations = [r['itemId'] for r in predictions]

                truth = []
                t_context = test.loc[test['c_id'] == cid]
                for idx, row in t_context.iterrows():
                    if row['u_id'] == uid:
                        truth.append(row['i_id'])
                #truth = list(test.loc[test['user'] == uid].loc[test['context'] == cid]['item'])
                print(predictions)
                print(recommendations)
                print(truth)

                for metric in self.metrics:
                    if str(metric) not in fold_scores.keys():
                        fold_scores[str(metric)] = []
                    score = metric.calculate(recommendations, truth)
                    fold_scores[str(metric)].append(score)

            result_for_fold = {'cid': cid}
            for metric_type, scores in fold_scores.items():
                avg = sum(scores) / len(scores)
                result_for_fold[metric_type] = avg

                if metric_type not in result['result'].keys():
                    result['result'][metric_type] = []
                result['result'][metric_type].append(avg)
            result['folds'].append(result_for_fold)

        final_results = {}
        for metric_type, score in result['result'].items():
            final_results[metric_type] = sum(score) / len(score)

        result['result'] = final_results
        return result

# %%
recommender = MatrixFactorization(graph)

evaluator = LeaveOneOutCrossValidation(recommender, metrics=parsed_metrics)
result = evaluator.evaluate(ratings)

for fold in result['folds']:
    print(fold)
print(result['result'])
# Out:
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 2, 'itemId': 51, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 22, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 52, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 48, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 26, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 56, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 49, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 54, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 55, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 53, 'score': 0.9998883430554173}]
# [51, 22, 52, 48, 26, 56, 49, 54, 55, 53]
# [22, 26]
# [{'contextId': 2, 'itemId': 52, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 56, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 54, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 51, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 26, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 49, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 22, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 55, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 48, 'score': 0.9998883430554173}, {'contextId': 2, 'itemId': 53, 'score': 0.9998883430554173}]
# [52, 56, 54, 51, 26, 49, 22, 55, 48, 53]
# [22, 26]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 3, 'itemId': 36, 'score': 1}, {'contextId': 3, 'itemId': 53, 'score': 1}, {'contextId': 3, 'itemId': 52, 'score': 1}, {'contextId': 3, 'itemId': 49, 'score': 1}, {'contextId': 3, 'itemId': 51, 'score': 1}, {'contextId': 3, 'itemId': 23, 'score': 1}, {'contextId': 3, 'itemId': 54, 'score': 1}, {'contextId': 3, 'itemId': 55, 'score': 1}, {'contextId': 3, 'itemId': 56, 'score': 1}, {'contextId': 3, 'itemId': 50, 'score': 1}]
# [36, 53, 52, 49, 51, 23, 54, 55, 56, 50]
# [23, 36]
# [{'contextId': 3, 'itemId': 53, 'score': 1}, {'contextId': 3, 'itemId': 55, 'score': 1}, {'contextId': 3, 'itemId': 36, 'score': 1}, {'contextId': 3, 'itemId': 50, 'score': 1}, {'contextId': 3, 'itemId': 49, 'score': 1}, {'contextId': 3, 'itemId': 52, 'score': 1}, {'contextId': 3, 'itemId': 51, 'score': 1}, {'contextId': 3, 'itemId': 56, 'score': 1}, {'contextId': 3, 'itemId': 54, 'score': 1}, {'contextId': 3, 'itemId': 23, 'score': 1}]
# [53, 55, 36, 50, 49, 52, 51, 56, 54, 23]
# [23, 36]
# [{'contextId': 3, 'itemId': 36, 'score': 1}, {'contextId': 3, 'itemId': 49, 'score': 1}, {'contextId': 3, 'itemId': 52, 'score': 1}, {'contextId': 3, 'itemId': 51, 'score': 1}, {'contextId': 3, 'itemId': 56, 'score': 1}, {'contextId': 3, 'itemId': 54, 'score': 1}, {'contextId': 3, 'itemId': 53, 'score': 1}, {'contextId': 3, 'itemId': 23, 'score': 1}, {'contextId': 3, 'itemId': 55, 'score': 1}, {'contextId': 3, 'itemId': 50, 'score': 1}]
# [36, 49, 52, 51, 56, 54, 53, 23, 55, 50]
# [23, 36]
# [{'contextId': 3, 'itemId': 36, 'score': 1}, {'contextId': 3, 'itemId': 23, 'score': 1}, {'contextId': 3, 'itemId': 50, 'score': 1}, {'contextId': 3, 'itemId': 53, 'score': 1}, {'contextId': 3, 'itemId': 51, 'score': 1}, {'contextId': 3, 'itemId': 54, 'score': 1}, {'contextId': 3, 'itemId': 49, 'score': 1}, {'contextId': 3, 'itemId': 56, 'score': 1}, {'contextId': 3, 'itemId': 55, 'score': 1}, {'contextId': 3, 'itemId': 52, 'score': 1}]
# [36, 23, 50, 53, 51, 54, 49, 56, 55, 52]
# [23, 36]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 7, 'itemId': 49, 'score': 1}, {'contextId': 7, 'itemId': 50, 'score': 1}, {'contextId': 7, 'itemId': 56, 'score': 1}, {'contextId': 7, 'itemId': 45, 'score': 1}, {'contextId': 7, 'itemId': 55, 'score': 1}, {'contextId': 7, 'itemId': 54, 'score': 1}, {'contextId': 7, 'itemId': 1, 'score': 1}, {'contextId': 7, 'itemId': 53, 'score': 1}, {'contextId': 7, 'itemId': 2, 'score': 1}, {'contextId': 7, 'itemId': 37, 'score': 1}]
# [49, 50, 56, 45, 55, 54, 1, 53, 2, 37]
# [45, 37, 1, 2]
# [{'contextId': 7, 'itemId': 53, 'score': 1}, {'contextId': 7, 'itemId': 54, 'score': 1}, {'contextId': 7, 'itemId': 49, 'score': 1}, {'contextId': 7, 'itemId': 1, 'score': 1}, {'contextId': 7, 'itemId': 55, 'score': 1}, {'contextId': 7, 'itemId': 37, 'score': 1}, {'contextId': 7, 'itemId': 56, 'score': 1}, {'contextId': 7, 'itemId': 45, 'score': 1}, {'contextId': 7, 'itemId': 2, 'score': 1}, {'contextId': 7, 'itemId': 50, 'score': 1}]
# [53, 54, 49, 1, 55, 37, 56, 45, 2, 50]
# [45, 37, 1, 2]
# [{'contextId': 7, 'itemId': 37, 'score': 1}, {'contextId': 7, 'itemId': 53, 'score': 1}, {'contextId': 7, 'itemId': 49, 'score': 1}, {'contextId': 7, 'itemId': 50, 'score': 1}, {'contextId': 7, 'itemId': 55, 'score': 1}, {'contextId': 7, 'itemId': 54, 'score': 1}, {'contextId': 7, 'itemId': 56, 'score': 1}, {'contextId': 7, 'itemId': 1, 'score': 1}, {'contextId': 7, 'itemId': 45, 'score': 1}, {'contextId': 7, 'itemId': 2, 'score': 1}]
# [37, 53, 49, 50, 55, 54, 56, 1, 45, 2]
# [45, 37, 1, 2]
# [{'contextId': 7, 'itemId': 45, 'score': 1}, {'contextId': 7, 'itemId': 56, 'score': 1}, {'contextId': 7, 'itemId': 50, 'score': 1}, {'contextId': 7, 'itemId': 2, 'score': 1}, {'contextId': 7, 'itemId': 53, 'score': 1}, {'contextId': 7, 'itemId': 49, 'score': 1}, {'contextId': 7, 'itemId': 54, 'score': 1}, {'contextId': 7, 'itemId': 1, 'score': 1}, {'contextId': 7, 'itemId': 55, 'score': 1}, {'contextId': 7, 'itemId': 37, 'score': 1}]
# [45, 56, 50, 2, 53, 49, 54, 1, 55, 37]
# [45, 37, 1, 2]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 14, 'itemId': 54, 'score': 1}, {'contextId': 14, 'itemId': 55, 'score': 1}, {'contextId': 14, 'itemId': 49, 'score': 1}, {'contextId': 14, 'itemId': 52, 'score': 1}, {'contextId': 14, 'itemId': 56, 'score': 1}, {'contextId': 14, 'itemId': 51, 'score': 1}, {'contextId': 14, 'itemId': 50, 'score': 1}, {'contextId': 14, 'itemId': 53, 'score': 1}, {'contextId': 14, 'itemId': 9, 'score': 1}, {'contextId': 14, 'itemId': 24, 'score': 1}]
# [54, 55, 49, 52, 56, 51, 50, 53, 9, 24]
# [9, 24]
# [{'contextId': 14, 'itemId': 50, 'score': 1}, {'contextId': 14, 'itemId': 55, 'score': 1}, {'contextId': 14, 'itemId': 54, 'score': 1}, {'contextId': 14, 'itemId': 51, 'score': 1}, {'contextId': 14, 'itemId': 9, 'score': 1}, {'contextId': 14, 'itemId': 52, 'score': 1}, {'contextId': 14, 'itemId': 56, 'score': 1}, {'contextId': 14, 'itemId': 53, 'score': 1}, {'contextId': 14, 'itemId': 24, 'score': 1}, {'contextId': 14, 'itemId': 49, 'score': 1}]
# [50, 55, 54, 51, 9, 52, 56, 53, 24, 49]
# [9, 24]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 5, 'itemId': 52, 'score': 1}, {'contextId': 5, 'itemId': 53, 'score': 1}, {'contextId': 5, 'itemId': 54, 'score': 1}, {'contextId': 5, 'itemId': 55, 'score': 1}, {'contextId': 5, 'itemId': 56, 'score': 1}, {'contextId': 5, 'itemId': 49, 'score': 1}, {'contextId': 5, 'itemId': 50, 'score': 1}, {'contextId': 5, 'itemId': 51, 'score': 1}, {'contextId': 5, 'itemId': 21, 'score': 1}, {'contextId': 5, 'itemId': 32, 'score': 1}]
# [52, 53, 54, 55, 56, 49, 50, 51, 21, 32]
# [21, 32]
# [{'contextId': 5, 'itemId': 55, 'score': 1}, {'contextId': 5, 'itemId': 51, 'score': 1}, {'contextId': 5, 'itemId': 54, 'score': 1}, {'contextId': 5, 'itemId': 52, 'score': 1}, {'contextId': 5, 'itemId': 56, 'score': 1}, {'contextId': 5, 'itemId': 49, 'score': 1}, {'contextId': 5, 'itemId': 50, 'score': 1}, {'contextId': 5, 'itemId': 53, 'score': 1}, {'contextId': 5, 'itemId': 21, 'score': 1}, {'contextId': 5, 'itemId': 32, 'score': 1}]
# [55, 51, 54, 52, 56, 49, 50, 53, 21, 32]
# [21, 32]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 16, 'itemId': 50, 'score': 0.9999895892186287}, {'contextId': 16, 'itemId': 51, 'score': 0.9999895892186287}, {'contextId': 16, 'itemId': 52, 'score': 0.9999895892186287}, {'contextId': 16, 'itemId': 53, 'score': 0.9999895892186287}, {'contextId': 16, 'itemId': 56, 'score': 0.9999895892186287}, {'contextId': 16, 'itemId': 48, 'score': 0.9999895892186287}, {'contextId': 16, 'itemId': 54, 'score': 0.9999895892186287}, {'contextId': 16, 'itemId': 55, 'score': 0.9999895892186287}, {'contextId': 16, 'itemId': 49, 'score': 0.9999895892186287}, {'contextId': 16, 'itemId': 28, 'score': 0.9999895892186287}]
# [50, 51, 52, 53, 56, 48, 54, 55, 49, 28]
# [28]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.03 - val_mae: 0.01 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.03 - val_mae: 0.01 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 13, 'itemId': 3, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 52, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 49, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 40, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 33, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 54, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 56, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 53, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 51, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 55, 'score': 0.9997480776237944}]
# [3, 52, 49, 40, 33, 54, 56, 53, 51, 55]
# [40, 3, 33]
# [{'contextId': 13, 'itemId': 51, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 56, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 52, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 33, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 3, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 40, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 53, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 49, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 54, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 55, 'score': 0.9997480776237944}]
# [51, 56, 52, 33, 3, 40, 53, 49, 54, 55]
# [40, 3, 33]
# [{'contextId': 13, 'itemId': 55, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 52, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 54, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 53, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 3, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 33, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 56, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 49, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 51, 'score': 0.9997480776237944}, {'contextId': 13, 'itemId': 40, 'score': 0.9997480776237944}]
# [55, 52, 54, 53, 3, 33, 56, 49, 51, 40]
# [40, 3, 33]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 9, 'itemId': 46, 'score': 1}, {'contextId': 9, 'itemId': 56, 'score': 1}, {'contextId': 9, 'itemId': 52, 'score': 1}, {'contextId': 9, 'itemId': 15, 'score': 1}, {'contextId': 9, 'itemId': 25, 'score': 1}, {'contextId': 9, 'itemId': 51, 'score': 1}, {'contextId': 9, 'itemId': 53, 'score': 1}, {'contextId': 9, 'itemId': 54, 'score': 1}, {'contextId': 9, 'itemId': 55, 'score': 1}, {'contextId': 9, 'itemId': 49, 'score': 1}]
# [46, 56, 52, 15, 25, 51, 53, 54, 55, 49]
# [15, 25, 46]
# [{'contextId': 9, 'itemId': 46, 'score': 1}, {'contextId': 9, 'itemId': 56, 'score': 1}, {'contextId': 9, 'itemId': 49, 'score': 1}, {'contextId': 9, 'itemId': 15, 'score': 1}, {'contextId': 9, 'itemId': 53, 'score': 1}, {'contextId': 9, 'itemId': 25, 'score': 1}, {'contextId': 9, 'itemId': 52, 'score': 1}, {'contextId': 9, 'itemId': 51, 'score': 1}, {'contextId': 9, 'itemId': 54, 'score': 1}, {'contextId': 9, 'itemId': 55, 'score': 1}]
# [46, 56, 49, 15, 53, 25, 52, 51, 54, 55]
# [15, 25, 46]
# [{'contextId': 9, 'itemId': 54, 'score': 1}, {'contextId': 9, 'itemId': 25, 'score': 1}, {'contextId': 9, 'itemId': 56, 'score': 1}, {'contextId': 9, 'itemId': 53, 'score': 1}, {'contextId': 9, 'itemId': 15, 'score': 1}, {'contextId': 9, 'itemId': 52, 'score': 1}, {'contextId': 9, 'itemId': 46, 'score': 1}, {'contextId': 9, 'itemId': 49, 'score': 1}, {'contextId': 9, 'itemId': 55, 'score': 1}, {'contextId': 9, 'itemId': 51, 'score': 1}]
# [54, 25, 56, 53, 15, 52, 46, 49, 55, 51]
# [15, 25, 46]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 12, 'itemId': 31, 'score': 1}, {'contextId': 12, 'itemId': 54, 'score': 1}, {'contextId': 12, 'itemId': 56, 'score': 1}, {'contextId': 12, 'itemId': 18, 'score': 1}, {'contextId': 12, 'itemId': 34, 'score': 1}, {'contextId': 12, 'itemId': 53, 'score': 1}, {'contextId': 12, 'itemId': 50, 'score': 1}, {'contextId': 12, 'itemId': 48, 'score': 1}, {'contextId': 12, 'itemId': 55, 'score': 1}, {'contextId': 12, 'itemId': 49, 'score': 1}]
# [31, 54, 56, 18, 34, 53, 50, 48, 55, 49]
# [34, 18, 31]
# [{'contextId': 12, 'itemId': 55, 'score': 1}, {'contextId': 12, 'itemId': 54, 'score': 1}, {'contextId': 12, 'itemId': 31, 'score': 1}, {'contextId': 12, 'itemId': 48, 'score': 1}, {'contextId': 12, 'itemId': 18, 'score': 1}, {'contextId': 12, 'itemId': 56, 'score': 1}, {'contextId': 12, 'itemId': 50, 'score': 1}, {'contextId': 12, 'itemId': 53, 'score': 1}, {'contextId': 12, 'itemId': 34, 'score': 1}, {'contextId': 12, 'itemId': 49, 'score': 1}]
# [55, 54, 31, 48, 18, 56, 50, 53, 34, 49]
# [34, 18, 31]
# [{'contextId': 12, 'itemId': 34, 'score': 1}, {'contextId': 12, 'itemId': 31, 'score': 1}, {'contextId': 12, 'itemId': 55, 'score': 1}, {'contextId': 12, 'itemId': 53, 'score': 1}, {'contextId': 12, 'itemId': 54, 'score': 1}, {'contextId': 12, 'itemId': 49, 'score': 1}, {'contextId': 12, 'itemId': 18, 'score': 1}, {'contextId': 12, 'itemId': 56, 'score': 1}, {'contextId': 12, 'itemId': 50, 'score': 1}, {'contextId': 12, 'itemId': 48, 'score': 1}]
# [34, 31, 55, 53, 54, 49, 18, 56, 50, 48]
# [34, 18, 31]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 6, 'itemId': 49, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 53, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 50, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 56, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 48, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 52, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 51, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 10, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 11, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 55, 'score': 0.9998975341402768}]
# [49, 53, 50, 56, 48, 52, 51, 10, 11, 55]
# [10, 11]
# [{'contextId': 6, 'itemId': 55, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 53, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 10, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 51, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 56, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 49, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 50, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 48, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 52, 'score': 0.9998975341402768}, {'contextId': 6, 'itemId': 11, 'score': 0.9998975341402768}]
# [55, 53, 10, 51, 56, 49, 50, 48, 52, 11]
# [10, 11]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 10, 'itemId': 53, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 55, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 17, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 16, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 50, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 48, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 56, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 49, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 54, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 12, 'score': 0.9998534312321667}]
# [53, 55, 17, 16, 50, 48, 56, 49, 54, 12]
# [12, 16, 17]
# [{'contextId': 10, 'itemId': 12, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 49, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 17, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 56, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 54, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 53, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 48, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 55, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 50, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 16, 'score': 0.9998534312321667}]
# [12, 49, 17, 56, 54, 53, 48, 55, 50, 16]
# [12, 16, 17]
# [{'contextId': 10, 'itemId': 12, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 48, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 49, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 53, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 17, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 54, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 16, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 56, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 50, 'score': 0.9998534312321667}, {'contextId': 10, 'itemId': 55, 'score': 0.9998534312321667}]
# [12, 48, 49, 53, 17, 54, 16, 56, 50, 55]
# [12, 16, 17]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 15, 'itemId': 48, 'score': 1}, {'contextId': 15, 'itemId': 49, 'score': 1}, {'contextId': 15, 'itemId': 41, 'score': 1}, {'contextId': 15, 'itemId': 55, 'score': 1}, {'contextId': 15, 'itemId': 54, 'score': 1}, {'contextId': 15, 'itemId': 42, 'score': 1}, {'contextId': 15, 'itemId': 56, 'score': 1}, {'contextId': 15, 'itemId': 53, 'score': 1}, {'contextId': 15, 'itemId': 14, 'score': 1}, {'contextId': 15, 'itemId': 50, 'score': 1}]
# [48, 49, 41, 55, 54, 42, 56, 53, 14, 50]
# [41, 42, 14]
# [{'contextId': 15, 'itemId': 50, 'score': 1}, {'contextId': 15, 'itemId': 48, 'score': 1}, {'contextId': 15, 'itemId': 55, 'score': 1}, {'contextId': 15, 'itemId': 14, 'score': 1}, {'contextId': 15, 'itemId': 53, 'score': 1}, {'contextId': 15, 'itemId': 42, 'score': 1}, {'contextId': 15, 'itemId': 49, 'score': 1}, {'contextId': 15, 'itemId': 41, 'score': 1}, {'contextId': 15, 'itemId': 54, 'score': 1}, {'contextId': 15, 'itemId': 56, 'score': 1}]
# [50, 48, 55, 14, 53, 42, 49, 41, 54, 56]
# [41, 42, 14]
# [{'contextId': 15, 'itemId': 50, 'score': 1}, {'contextId': 15, 'itemId': 54, 'score': 1}, {'contextId': 15, 'itemId': 55, 'score': 1}, {'contextId': 15, 'itemId': 49, 'score': 1}, {'contextId': 15, 'itemId': 42, 'score': 1}, {'contextId': 15, 'itemId': 41, 'score': 1}, {'contextId': 15, 'itemId': 48, 'score': 1}, {'contextId': 15, 'itemId': 56, 'score': 1}, {'contextId': 15, 'itemId': 14, 'score': 1}, {'contextId': 15, 'itemId': 53, 'score': 1}]
# [50, 54, 55, 49, 42, 41, 48, 56, 14, 53]
# [41, 42, 14]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.02 - val_mae: 0.01 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.02 - val_mae: 0.01 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 8, 'itemId': 54, 'score': 0.9999771790023172}, {'contextId': 8, 'itemId': 56, 'score': 0.9999771790023172}, {'contextId': 8, 'itemId': 52, 'score': 0.9999771790023172}, {'contextId': 8, 'itemId': 50, 'score': 0.9999771790023172}, {'contextId': 8, 'itemId': 53, 'score': 0.9999771790023172}, {'contextId': 8, 'itemId': 51, 'score': 0.9999771790023172}, {'contextId': 8, 'itemId': 55, 'score': 0.9999771790023172}, {'contextId': 8, 'itemId': 4, 'score': 0.9999771790023172}, {'contextId': 8, 'itemId': 48, 'score': 0.9999771790023172}, {'contextId': 8, 'itemId': 49, 'score': 0.9999771790023172}]
# [54, 56, 52, 50, 53, 51, 55, 4, 48, 49]
# [4]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 4, 'itemId': 0, 'score': 1}, {'contextId': 4, 'itemId': 53, 'score': 1}, {'contextId': 4, 'itemId': 49, 'score': 1}, {'contextId': 4, 'itemId': 38, 'score': 1}, {'contextId': 4, 'itemId': 56, 'score': 1}, {'contextId': 4, 'itemId': 6, 'score': 1}, {'contextId': 4, 'itemId': 55, 'score': 1}, {'contextId': 4, 'itemId': 54, 'score': 1}, {'contextId': 4, 'itemId': 13, 'score': 1}, {'contextId': 4, 'itemId': 50, 'score': 1}]
# [0, 53, 49, 38, 56, 6, 55, 54, 13, 50]
# [6, 13, 38, 0]
# [{'contextId': 4, 'itemId': 53, 'score': 1}, {'contextId': 4, 'itemId': 13, 'score': 1}, {'contextId': 4, 'itemId': 55, 'score': 1}, {'contextId': 4, 'itemId': 0, 'score': 1}, {'contextId': 4, 'itemId': 50, 'score': 1}, {'contextId': 4, 'itemId': 38, 'score': 1}, {'contextId': 4, 'itemId': 54, 'score': 1}, {'contextId': 4, 'itemId': 6, 'score': 1}, {'contextId': 4, 'itemId': 56, 'score': 1}, {'contextId': 4, 'itemId': 49, 'score': 1}]
# [53, 13, 55, 0, 50, 38, 54, 6, 56, 49]
# [6, 13, 38, 0]
# [{'contextId': 4, 'itemId': 6, 'score': 1}, {'contextId': 4, 'itemId': 53, 'score': 1}, {'contextId': 4, 'itemId': 56, 'score': 1}, {'contextId': 4, 'itemId': 38, 'score': 1}, {'contextId': 4, 'itemId': 54, 'score': 1}, {'contextId': 4, 'itemId': 49, 'score': 1}, {'contextId': 4, 'itemId': 0, 'score': 1}, {'contextId': 4, 'itemId': 13, 'score': 1}, {'contextId': 4, 'itemId': 55, 'score': 1}, {'contextId': 4, 'itemId': 50, 'score': 1}]
# [6, 53, 56, 38, 54, 49, 0, 13, 55, 50]
# [6, 13, 38, 0]
# [{'contextId': 4, 'itemId': 56, 'score': 1}, {'contextId': 4, 'itemId': 38, 'score': 1}, {'contextId': 4, 'itemId': 6, 'score': 1}, {'contextId': 4, 'itemId': 53, 'score': 1}, {'contextId': 4, 'itemId': 55, 'score': 1}, {'contextId': 4, 'itemId': 13, 'score': 1}, {'contextId': 4, 'itemId': 54, 'score': 1}, {'contextId': 4, 'itemId': 0, 'score': 1}, {'contextId': 4, 'itemId': 50, 'score': 1}, {'contextId': 4, 'itemId': 49, 'score': 1}]
# [56, 38, 6, 53, 55, 13, 54, 0, 50, 49]
# [6, 13, 38, 0]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.01 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 0, 'itemId': 43, 'score': 1}, {'contextId': 0, 'itemId': 54, 'score': 1}, {'contextId': 0, 'itemId': 53, 'score': 1}, {'contextId': 0, 'itemId': 50, 'score': 1}, {'contextId': 0, 'itemId': 49, 'score': 1}, {'contextId': 0, 'itemId': 52, 'score': 1}, {'contextId': 0, 'itemId': 44, 'score': 1}, {'contextId': 0, 'itemId': 51, 'score': 1}, {'contextId': 0, 'itemId': 55, 'score': 1}, {'contextId': 0, 'itemId': 56, 'score': 1}]
# [43, 54, 53, 50, 49, 52, 44, 51, 55, 56]
# [44, 43]
# [{'contextId': 0, 'itemId': 43, 'score': 1}, {'contextId': 0, 'itemId': 49, 'score': 1}, {'contextId': 0, 'itemId': 44, 'score': 1}, {'contextId': 0, 'itemId': 52, 'score': 1}, {'contextId': 0, 'itemId': 53, 'score': 1}, {'contextId': 0, 'itemId': 55, 'score': 1}, {'contextId': 0, 'itemId': 56, 'score': 1}, {'contextId': 0, 'itemId': 51, 'score': 1}, {'contextId': 0, 'itemId': 54, 'score': 1}, {'contextId': 0, 'itemId': 50, 'score': 1}]
# [43, 49, 44, 52, 53, 55, 56, 51, 54, 50]
# [44, 43]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.02 - val_mae: 0.01 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.02 - val_mae: 0.01 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 11, 'itemId': 51, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 55, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 29, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 52, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 56, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 35, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 49, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 50, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 30, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 53, 'score': 0.9998478451041894}]
# [51, 55, 29, 52, 56, 35, 49, 50, 30, 53]
# [30, 35, 29]
# [{'contextId': 11, 'itemId': 50, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 52, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 56, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 53, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 29, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 51, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 55, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 49, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 35, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 30, 'score': 0.9998478451041894}]
# [50, 52, 56, 53, 29, 51, 55, 49, 35, 30]
# [30, 35, 29]
# [{'contextId': 11, 'itemId': 52, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 55, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 35, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 56, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 49, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 53, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 29, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 50, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 51, 'score': 0.9998478451041894}, {'contextId': 11, 'itemId': 30, 'score': 0.9998478451041894}]
# [52, 55, 35, 56, 49, 53, 29, 50, 51, 30]
# [30, 35, 29]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.03 - val_mae: 0.01 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.03 - val_mae: 0.01 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 17, 'itemId': 50, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 51, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 52, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 19, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 8, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 55, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 49, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 48, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 53, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 56, 'score': 0.9998600983539664}]
# [50, 51, 52, 19, 8, 55, 49, 48, 53, 56]
# [19, 8]
# [{'contextId': 17, 'itemId': 56, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 53, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 55, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 19, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 50, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 8, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 49, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 51, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 52, 'score': 0.9998600983539664}, {'contextId': 17, 'itemId': 48, 'score': 0.9998600983539664}]
# [56, 53, 55, 19, 50, 8, 49, 51, 52, 48]
# [19, 8]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 18, 'itemId': 54, 'score': 1}, {'contextId': 18, 'itemId': 53, 'score': 1}, {'contextId': 18, 'itemId': 7, 'score': 1}, {'contextId': 18, 'itemId': 55, 'score': 1}, {'contextId': 18, 'itemId': 49, 'score': 1}, {'contextId': 18, 'itemId': 51, 'score': 1}, {'contextId': 18, 'itemId': 48, 'score': 1}, {'contextId': 18, 'itemId': 52, 'score': 1}, {'contextId': 18, 'itemId': 56, 'score': 1}, {'contextId': 18, 'itemId': 50, 'score': 1}]
# [54, 53, 7, 55, 49, 51, 48, 52, 56, 50]
# [7]
# Preprocessing data...
#
# Preprocessing data...
#
# Epoch 1/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
# Epoch 2/100  | val_loss: 0.00 - val_rmse: 0.00 - val_mae: 0.00 - took 0.0 sec
#
# Training took 0 sec
# [{'contextId': 1, 'itemId': 54, 'score': 1}, {'contextId': 1, 'itemId': 55, 'score': 1}, {'contextId': 1, 'itemId': 49, 'score': 1}, {'contextId': 1, 'itemId': 20, 'score': 1}, {'contextId': 1, 'itemId': 53, 'score': 1}, {'contextId': 1, 'itemId': 47, 'score': 1}, {'contextId': 1, 'itemId': 27, 'score': 1}, {'contextId': 1, 'itemId': 39, 'score': 1}, {'contextId': 1, 'itemId': 48, 'score': 1}, {'contextId': 1, 'itemId': 5, 'score': 1}]
# [54, 55, 49, 20, 53, 47, 27, 39, 48, 5]
# [39, 27, 5, 20]
# [{'contextId': 1, 'itemId': 47, 'score': 1}, {'contextId': 1, 'itemId': 39, 'score': 1}, {'contextId': 1, 'itemId': 20, 'score': 1}, {'contextId': 1, 'itemId': 49, 'score': 1}, {'contextId': 1, 'itemId': 53, 'score': 1}, {'contextId': 1, 'itemId': 5, 'score': 1}, {'contextId': 1, 'itemId': 54, 'score': 1}, {'contextId': 1, 'itemId': 48, 'score': 1}, {'contextId': 1, 'itemId': 55, 'score': 1}, {'contextId': 1, 'itemId': 27, 'score': 1}]
# [47, 39, 20, 49, 53, 5, 54, 48, 55, 27]
# [39, 27, 5, 20]
# [{'contextId': 1, 'itemId': 54, 'score': 1}, {'contextId': 1, 'itemId': 47, 'score': 1}, {'contextId': 1, 'itemId': 20, 'score': 1}, {'contextId': 1, 'itemId': 48, 'score': 1}, {'contextId': 1, 'itemId': 5, 'score': 1}, {'contextId': 1, 'itemId': 49, 'score': 1}, {'contextId': 1, 'itemId': 53, 'score': 1}, {'contextId': 1, 'itemId': 39, 'score': 1}, {'contextId': 1, 'itemId': 55, 'score': 1}, {'contextId': 1, 'itemId': 27, 'score': 1}]
# [54, 47, 20, 48, 5, 49, 53, 39, 55, 27]
# [39, 27, 5, 20]
# [{'contextId': 1, 'itemId': 53, 'score': 1}, {'contextId': 1, 'itemId': 47, 'score': 1}, {'contextId': 1, 'itemId': 20, 'score': 1}, {'contextId': 1, 'itemId': 27, 'score': 1}, {'contextId': 1, 'itemId': 39, 'score': 1}, {'contextId': 1, 'itemId': 48, 'score': 1}, {'contextId': 1, 'itemId': 49, 'score': 1}, {'contextId': 1, 'itemId': 5, 'score': 1}, {'contextId': 1, 'itemId': 55, 'score': 1}, {'contextId': 1, 'itemId': 54, 'score': 1}]
# [53, 47, 20, 27, 39, 48, 49, 5, 55, 54]
# [39, 27, 5, 20]
# {'cid': 2, 'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.19342640361727081}
# {'cid': 3, 'f1@1': 0.5, 'ndcg@1': 0.4598603945740938, 'ndcg@3': 0.6332169954784115}
# {'cid': 7, 'f1@1': 0.2, 'ndcg@1': 0.19519002499605084, 'ndcg@3': 0.19519002499605084}
# {'cid': 14, 'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.0}
# {'cid': 5, 'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.0}
# {'cid': 16, 'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.0}
# {'cid': 13, 'f1@1': 0.16666666666666666, 'ndcg@1': 0.15642624200758548, 'ndcg@3': 0.15642624200758548}
# {'cid': 9, 'f1@1': 0.3333333333333333, 'ndcg@1': 0.31285248401517096, 'ndcg@3': 0.41154645433712606}
# {'cid': 12, 'f1@1': 0.3333333333333333, 'ndcg@1': 0.31285248401517096, 'ndcg@3': 0.48975957534091874}
# {'cid': 6, 'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.1532867981913646}
# {'cid': 10, 'f1@1': 0.3333333333333333, 'ndcg@1': 0.31285248401517096, 'ndcg@3': 0.46927872602275644}
# {'cid': 15, 'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.07821312100379274}
# {'cid': 8, 'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.0}
# {'cid': 4, 'f1@1': 0.2, 'ndcg@1': 0.19519002499605084, 'ndcg@3': 0.36713872561542854}
# {'cid': 0, 'f1@1': 0.6666666666666666, 'ndcg@1': 0.6131471927654584, 'ndcg@3': 0.766433990956823}
# {'cid': 11, 'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.15642624200758548}
# {'cid': 17, 'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.0}
# {'cid': 18, 'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.5}
# {'cid': 1, 'f1@1': 0.0, 'ndcg@1': 0.0, 'ndcg@3': 0.20796811593222064}
# {'f1@1': 0.143859649122807, 'ndcg@1': 0.13465112270446064, 'ndcg@3': 0.251490074500386}
